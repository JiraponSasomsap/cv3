# %%
import cv2
import os
from pathlib import Path

img_path = r''
point = []
# This function will be called whenever the mouse is clicked
def get_coordinates(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        print(f"Coordinates: ({x}, {y})")
        point.append([x/new_w,y/new_h]) # x, y
        print(point)
        cv2.circle(img, (x, y), 5, (0, 255, 0), -1)
        cv2.imshow("Image", img)
 
# Load the image
if img_path == '':
    img_path = input('Enter image path : ')
    img_path = img_path.replace('"', '').replace("'", "")
print(img_path)
img = cv2.imread(img_path)
 
h, w = img.shape[:2]
img = cv2.resize(img, (int(w*0.5), int(h*0.5)))
new_h, new_w = img.shape[:2]
 
# Create a window and set a callback function for mouse events
cv2.imshow("Image", img)
cv2.setMouseCallback("Image", get_coordinates)
window_x = 150  # x-coordinate
window_y = 50  # y-coordinate
cv2.moveWindow("Image", window_x, window_y)
 
# Keep the window open until a key is pressed
cv2.waitKey(0)
cv2.destroyAllWindows()
